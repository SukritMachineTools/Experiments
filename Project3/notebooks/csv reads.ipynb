# %%
#imports
import datetime
import pandas as pd

# %%
#read google sheets 
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vT6HrGh7EOzzejrvzkG_TGUM_GoGVDuvlUq7UcYqHlESZX6Vv8Hvwatsp4FLdE4Nmff9z5LSG3KQFq9/pub?gid=1362009325&single=true&output=csv')

# %%
df
# Out:
#          Date   Machines Operator              Job  Total Prod Rejection  \
# 0         NaN        NaN      NaN              NaN         NaN       M/C
# 1    1-6-2023  M/C No. 2     Sukh             test        10.0         1
# 2    2-6-2023  M/C No. 7     Sukh  ALU. BUSH ROUGH        10.0         1
# 3    2-6-2023  M/C No. 2     Sukh   S.R. Shaft THD        12.0         1
# 4    2-6-2023  M/C No. 2     Sukh   S.R. Shaft THD        15.0         6
# 5    2-6-2023  M/C No. 2     Sukh             test        25.0        10
# 6   20-5-2023  M/C No. 2     Sukh   S.R. Shaft THD        10.0         1
# 7   21-5-2023  M/C No. 3     Sukh   S.R. Shaft THD        10.0         1
# 8   22-5-2023  M/C No. 4     Sukh             test        10.0         1
# 9   23-5-2023  M/C No. 5     Sukh   S.R. Shaft THD        10.0         1
# 10  24-5-2023  M/C No. 6     Sukh   S.R. Shaft THD        10.0         1
# 11  25-5-2023  M/C No. 7     Sukh             test        10.0         1
# 12  26-5-2023  M/C No. 8      som   S.R. Shaft THD        10.0         1
# 13  27-5-2023  M/C No. 9      som   S.R. Shaft THD        10.0         1
# 14   3-7-2023  M/C No. 6      som   S.R. Shaft THD         9.0         0
# 15   3-7-2023  M/C No. 2      som  ALU. BUSH FINAL        10.0         1
# 16   3-7-2023  M/C No. 2      som  ALU. BUSH FINAL       100.0         8
# 17   4-7-2023  M/C No. 3      som  ALU. BUSH FINAL       100.0         8
# 18   5-7-2023  M/C No. 4    happy   S.R. Shaft THD       100.0         8
# 19   6-7-2023  M/C No. 5    happy   S.R. Shaft THD       100.0         8
# 20   7-7-2023  M/C No. 6    happy   S.R. Shaft THD       100.0         8
#
#    Unnamed: 6 Unnamed: 7  Total Rej  Final Prod     Timming Unnamed: 11
# 0     Casting      Other        NaN         NaN  Start Time    End Time
# 1           2          3        6.0         4.0       08:30       15:30
# 2           2          3        6.0         4.0       08:30       05:30
# 3           2          3        6.0         6.0       08:00       12:00
# 4           0          1        7.0         8.0       08:30       13:30
# 5           5          3       18.0         7.0       08:30       13:30
# 6           3          2        6.0         4.0       10:30       15:00
# 7           3          2        6.0         4.0       11:30       16:00
# 8           3          2        6.0         4.0       12:30       17:00
# 9           3          2        6.0         4.0       13:30       18:00
# 10          3          2        6.0         4.0       14:30       19:00
# 11          3          2        6.0         4.0       15:30       20:00
# 12          3          2        6.0         4.0       16:30       21:00
# 13          3          2        6.0         4.0       17:30       22:00
# 14          1          0        1.0         8.0       08:10       21:30
# 15          1          2        4.0         6.0       08:30       21:10
# 16          9         10       27.0        73.0       09:00       19:30
# 17          9         10       27.0        73.0       10:00       20:30
# 18          9         10       27.0        73.0       11:00       21:30
# 19          9         10       27.0        73.0       11:50       22:30
# 20          9         10       27.0        73.0       13:00       23:30

# %%
#renamed columns
df.rename(columns = {'Rejection':'M/C', 'Unnamed: 6':'CASTING',
                              'Unnamed: 7':'OTHER','Timming':'Start_Time','Unnamed: 11':'End_Time','Total Prod':'Total_Prod','Final Prod':'Final_Prod','Total Rej':'Total_Rej'}, inplace = True)

# %%
df=df.drop(index=0)
df=df.reset_index(drop=True)

# %%
type(df.loc[0,'Date'])
# Out:
# str

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%d-%m-%Y')

# %%
# Convert the 'time_string' column to time object
df['Start_Time'] = pd.to_datetime(df['Start_Time'], format='%H:%M')
df['End_Time'] = pd.to_datetime(df['End_Time'], format='%H:%M')


# Calculate the time difference
 
df['time_difference1'] = df['End_Time'] - df['Start_Time'] 
df['time_difference1'] = df['time_difference1'] - pd.Timedelta(hours=1, minutes=30)
df['time_difference'] = df['time_difference1'].apply(lambda x: '{:02d}:{:02d}'.format(int(x.seconds // 3600), int((x.seconds // 60) % 60)))

df['Start_Time'] = pd.to_datetime(df['Start_Time'], format='%H:%M').dt.time
df['End_Time'] = pd.to_datetime(df['End_Time'], format='%H:%M').dt.time
df['time_difference'] = pd.to_datetime(df['time_difference'], format='%H:%M').dt.time

# Display the DataFrame
print(df)
# Out:
#          Date   Machines Operator              Job  Total_Prod M/C CASTING  \
# 0  2023-06-01  M/C No. 2     Sukh             test        10.0   1       2
# 1  2023-06-02  M/C No. 7     Sukh  ALU. BUSH ROUGH        10.0   1       2
# 2  2023-06-02  M/C No. 2     Sukh   S.R. Shaft THD        12.0   1       2
# 3  2023-06-02  M/C No. 2     Sukh   S.R. Shaft THD        15.0   6       0
# 4  2023-06-02  M/C No. 2     Sukh             test        25.0  10       5
# 5  2023-05-20  M/C No. 2     Sukh   S.R. Shaft THD        10.0   1       3
# 6  2023-05-21  M/C No. 3     Sukh   S.R. Shaft THD        10.0   1       3
# 7  2023-05-22  M/C No. 4     Sukh             test        10.0   1       3
# 8  2023-05-23  M/C No. 5     Sukh   S.R. Shaft THD        10.0   1       3
# 9  2023-05-24  M/C No. 6     Sukh   S.R. Shaft THD        10.0   1       3
# 10 2023-05-25  M/C No. 7     Sukh             test        10.0   1       3
# 11 2023-05-26  M/C No. 8      som   S.R. Shaft THD        10.0   1       3
# 12 2023-05-27  M/C No. 9      som   S.R. Shaft THD        10.0   1       3
# 13 2023-07-03  M/C No. 6      som   S.R. Shaft THD         9.0   0       1
# 14 2023-07-03  M/C No. 2      som  ALU. BUSH FINAL        10.0   1       1
# 15 2023-07-03  M/C No. 2      som  ALU. BUSH FINAL       100.0   8       9
# 16 2023-07-04  M/C No. 3      som  ALU. BUSH FINAL       100.0   8       9
# 17 2023-07-05  M/C No. 4    happy   S.R. Shaft THD       100.0   8       9
# 18 2023-07-06  M/C No. 5    happy   S.R. Shaft THD       100.0   8       9
# 19 2023-07-07  M/C No. 6    happy   S.R. Shaft THD       100.0   8       9
#
#    OTHER  Total_Rej  Final_Prod Start_Time  End_Time  time_difference1  \
# 0      3        6.0         4.0   08:30:00  15:30:00   0 days 05:30:00
# 1      3        6.0         4.0   08:30:00  05:30:00 -1 days +19:30:00
# 2      3        6.0         6.0   08:00:00  12:00:00   0 days 02:30:00
# 3      1        7.0         8.0   08:30:00  13:30:00   0 days 03:30:00
# 4      3       18.0         7.0   08:30:00  13:30:00   0 days 03:30:00
# 5      2        6.0         4.0   10:30:00  15:00:00   0 days 03:00:00
# 6      2        6.0         4.0   11:30:00  16:00:00   0 days 03:00:00
# 7      2        6.0         4.0   12:30:00  17:00:00   0 days 03:00:00
# 8      2        6.0         4.0   13:30:00  18:00:00   0 days 03:00:00
# 9      2        6.0         4.0   14:30:00  19:00:00   0 days 03:00:00
# 10     2        6.0         4.0   15:30:00  20:00:00   0 days 03:00:00
# 11     2        6.0         4.0   16:30:00  21:00:00   0 days 03:00:00
# 12     2        6.0         4.0   17:30:00  22:00:00   0 days 03:00:00
# 13     0        1.0         8.0   08:10:00  21:30:00   0 days 11:50:00
# 14     2        4.0         6.0   08:30:00  21:10:00   0 days 11:10:00
# 15    10       27.0        73.0   09:00:00  19:30:00   0 days 09:00:00
# 16    10       27.0        73.0   10:00:00  20:30:00   0 days 09:00:00
# 17    10       27.0        73.0   11:00:00  21:30:00   0 days 09:00:00
# 18    10       27.0        73.0   11:50:00  22:30:00   0 days 09:10:00
# 19    10       27.0        73.0   13:00:00  23:30:00   0 days 09:00:00
#
#    time_difference
# 0         05:30:00
# 1         19:30:00
# 2         02:30:00
# 3         03:30:00
# 4         03:30:00
# 5         03:00:00
# 6         03:00:00
# 7         03:00:00
# 8         03:00:00
# 9         03:00:00
# 10        03:00:00
# 11        03:00:00
# 12        03:00:00
# 13        11:50:00
# 14        11:10:00
# 15        09:00:00
# 16        09:00:00
# 17        09:00:00
# 18        09:10:00
# 19        09:00:00

# %%
job='S.R. Shaft THD'
breakTime='01:30'
start_date= '2023-06-01'
end_date= '2023-07-07'

# mask = (df['date'] > start_date) & (df['date'] <= end_date)
mask = (df['Date'] > start_date) & (df['Date'] <= end_date)
datedf=df.loc[mask]
newdf= datedf[datedf['Job']==job]
newdf=newdf.reset_index(drop=True)
newdf = newdf.astype({'Total_Prod':'int','M/C':'int','CASTING':'int','OTHER':'int','Total_Rej':'int','Final_Prod':'int'})
newdf['Date'] = newdf['Date'].dt.strftime('%d-%m-%Y')  
newdf
# Out:
#          Date   Machines Operator             Job  Total_Prod  M/C  CASTING  \
# 0  02-06-2023  M/C No. 2     Sukh  S.R. Shaft THD          12    1        2
# 1  02-06-2023  M/C No. 2     Sukh  S.R. Shaft THD          15    6        0
# 2  03-07-2023  M/C No. 6      som  S.R. Shaft THD           9    0        1
# 3  05-07-2023  M/C No. 4    happy  S.R. Shaft THD         100    8        9
# 4  06-07-2023  M/C No. 5    happy  S.R. Shaft THD         100    8        9
# 5  07-07-2023  M/C No. 6    happy  S.R. Shaft THD         100    8        9
#
#    OTHER  Total_Rej  Final_Prod Start_Time  End_Time time_difference1  \
# 0      3          6           6   08:00:00  12:00:00  0 days 02:30:00
# 1      1          7           8   08:30:00  13:30:00  0 days 03:30:00
# 2      0          1           8   08:10:00  21:30:00  0 days 11:50:00
# 3     10         27          73   11:00:00  21:30:00  0 days 09:00:00
# 4     10         27          73   11:50:00  22:30:00  0 days 09:10:00
# 5     10         27          73   13:00:00  23:30:00  0 days 09:00:00
#
#   time_difference
# 0        02:30:00
# 1        03:30:00
# 2        11:50:00
# 3        09:00:00
# 4        09:10:00
# 5        09:00:00

# %%
total_time = newdf['time_difference1'].sum()
# df=df.drop(['time_difference1'], axis=1)
total_hours = total_time.total_seconds() / 3600

print(total_hours)

sumrow={'Date':'Total', 'Total_Prod':sum(newdf['Total_Prod']),'M/C':sum(newdf['M/C']),'CASTING':sum(newdf['CASTING']),'OTHER':sum(newdf['OTHER']),'Final_Prod':sum(newdf['Final_Prod']),'time_difference':total_hours}
sumrow= pd.DataFrame(sumrow,index=['Total'])
newdf = pd.concat([newdf, sumrow], axis=0)
newdf
# Out:
# 45.0
#              Date   Machines Operator             Job  Total_Prod  M/C  \
# 0      02-06-2023  M/C No. 2     Sukh  S.R. Shaft THD          12    1
# 1      02-06-2023  M/C No. 2     Sukh  S.R. Shaft THD          15    6
# 2      03-07-2023  M/C No. 6      som  S.R. Shaft THD           9    0
# 3      05-07-2023  M/C No. 4    happy  S.R. Shaft THD         100    8
# 4      06-07-2023  M/C No. 5    happy  S.R. Shaft THD         100    8
# 5      07-07-2023  M/C No. 6    happy  S.R. Shaft THD         100    8
# Total       Total        NaN      NaN             NaN         336   31
#
#        CASTING  OTHER  Total_Rej  Final_Prod Start_Time  End_Time  \
# 0            2      3        6.0           6   08:00:00  12:00:00
# 1            0      1        7.0           8   08:30:00  13:30:00
# 2            1      0        1.0           8   08:10:00  21:30:00
# 3            9     10       27.0          73   11:00:00  21:30:00
# 4            9     10       27.0          73   11:50:00  22:30:00
# 5            9     10       27.0          73   13:00:00  23:30:00
# Total       30     34        NaN         241        NaN       NaN
#
#       time_difference1 time_difference
# 0      0 days 02:30:00        02:30:00
# 1      0 days 03:30:00        03:30:00
# 2      0 days 11:50:00        11:50:00
# 3      0 days 09:00:00        09:00:00
# 4      0 days 09:10:00        09:10:00
# 5      0 days 09:00:00        09:00:00
# Total              NaT            45.0

# %%
newdf.shape[0]
# Out:
# 7

# %%
# Get the distinct values in a specific column
distinct_values = newdf['Operator'].unique()  # Replace 'column_name' with the actual column name

distinct_values=list(distinct_values)
distinct_values.pop()
distinct_values
# Out:
# ['Sukh', 'som', 'happy']

# %%
op1=newdf[newdf['Operator']==distinct_values[0]]
days=op1.shape[0]
total_timeop = op1['time_difference1'].sum()
# df=df.drop(['time_difference1'], axis=1)
total_hoursop = total_timeop.total_seconds() / 3600
sum_prodop=sum(op1['Total_Prod'])
sum_mcop=sum(op1['M/C'])
sum_castop=sum(op1['CASTING'])
sum_otherop=sum(op1['OTHER'])
sum_finalprodop=sum(op1['Final_Prod'])

avg_hourlyop=round((sum_prodop/total_hoursop),2)
avg_dayop=round((sum_prodop/days),2)
print(days, total_hoursop, sum_prodop, sum_mcop, sum_castop, sum_otherop, sum_finalprodop, avg_hourlyop, avg_dayop)
# Out:
# 2 6.0 27 7 2 4 14 4.5 13.5

# %%
days=[] 
total_hours =[]
sum_prod=[]
sum_mc=[]
sum_cast=[]
sum_other=[]
sum_finalprod=[]
avg_hourly=[]
avg_day=[]
for i in range(len(distinct_values)):
    op1=newdf[newdf['Operator']==distinct_values[i]]
    daysop=op1.shape[0]
    days.append(daysop)
    total_timeop = op1['time_difference1'].sum()
    total_hoursop = round((total_timeop.total_seconds() / 3600),2)
    total_hours.append(total_hoursop)
    sum_prodop=sum(op1['Total_Prod'])
    sum_prod.append(sum_prodop)
    sum_mcop=sum(op1['M/C'])
    sum_mc.append(sum_mcop)
    sum_castop=sum(op1['CASTING'])
    sum_cast.append(sum_castop)
    sum_otherop=sum(op1['OTHER'])
    sum_other.append(sum_otherop)
    sum_finalprodop=sum(op1['Final_Prod'])
    sum_finalprod.append(sum_finalprodop)
    avg_hourlyop=round((sum_prodop/total_hoursop),2)
    avg_hourly.append(avg_hourlyop)
    avg_dayop=round((sum_prodop/daysop),2)
    avg_day.append(avg_dayop)
product={
    'Operator':distinct_values,
    'DAYS':days,
    'HOURS': total_hours,
    'Total_Prod':sum_prod,
    'M/C':sum_mc,
    'Casting':sum_cast,
    'Other':sum_other,
    'Final_Prod':sum_finalprod,
    'Hourly_Avg':avg_hourly,
    'Day_Avg':avg_day
}
print(product)
prod_df=pd.DataFrame(product)
prod_df['Deduct_Machine_rej']=prod_df['Total_Prod']-prod_df['M/C']
targetv=55
incentivev=0.70
prod_df['Hours X Target']=prod_df['HOURS']*targetv
prod_df['Extra Prod']=prod_df['Deduct_Machine_rej']-prod_df['Hours X Target']
prod_df['Incentive']=prod_df['Extra Prod']*incentivev
prod_df
# Out:
# {'Operator': ['Sukh', 'som', 'happy'], 'DAYS': [2, 1, 3], 'HOURS': [6.0, 11.83, 27.17], 'Total_Prod': [27, 9, 300], 'M/C': [7, 0, 24], 'Casting': [2, 1, 27], 'Other': [4, 0, 30], 'Final_Prod': [14, 8, 219], 'Hourly_Avg': [4.5, 0.76, 11.04], 'Day_Avg': [13.5, 9.0, 100.0]}
#   Operator  DAYS  HOURS  Total_Prod  M/C  Casting  Other  Final_Prod  \
# 0     Sukh     2   6.00          27    7        2      4          14
# 1      som     1  11.83           9    0        1      0           8
# 2    happy     3  27.17         300   24       27     30         219
#
#    Hourly_Avg  Day_Avg  Deduct_Machine_rej  Hours X Target  Extra Prod  \
# 0        4.50     13.5                  20          330.00     -310.00
# 1        0.76      9.0                   9          650.65     -641.65
# 2       11.04    100.0                 276         1494.35    -1218.35
#
#    Incentive
# 0   -217.000
# 1   -449.155
# 2   -852.845

# %%
op1
# Out:
#          Date   Machines Operator             Job  Total_Prod  M/C  CASTING  \
# 3  05-07-2023  M/C No. 4    happy  S.R. Shaft THD         100    8        9
# 4  06-07-2023  M/C No. 5    happy  S.R. Shaft THD         100    8        9
# 5  07-07-2023  M/C No. 6    happy  S.R. Shaft THD         100    8        9
#
#    OTHER  Total_Rej  Final_Prod Start_Time  End_Time time_difference1  \
# 3     10       27.0          73   11:00:00  21:30:00  0 days 09:00:00
# 4     10       27.0          73   11:50:00  22:30:00  0 days 09:10:00
# 5     10       27.0          73   13:00:00  23:30:00  0 days 09:00:00
#
#   time_difference
# 3        09:00:00
# 4        09:10:00
# 5        09:00:00

# %%
# Get the distinct values in a specific column
distinct_values_Job = df['Job'].unique()  
distinct_values_Job=list(distinct_values_Job)
distinct_values_Job.pop()
distinct_values_Job
# Out:
# ['test', 'ALU. BUSH ROUGH', 'S.R. Shaft THD']

# %%
#multi table
machinej=[]
t_prodj=[]
mcj=[]
castj=[]
otherj=[]
final=[]
column_names = ['Machines', 'PRODUCT', 'Total_Prod','M/C','CASTING','OTHER','FINAL']
dflist=[]
# Create an empty dataframe with the specified column names
jobs = pd.DataFrame(columns=column_names)

for j in range(len(distinct_values_Job)):
    job1=df[df['Job']==distinct_values_Job[j]]
    job1=job1.loc[mask]
    job1=job1.reset_index(drop=True)
    job1 = job1.astype({'Total_Prod':'int','M/C':'int','CASTING':'int','OTHER':'int','Total_Rej':'int','Final_Prod':'int'})
    distinct_values_Mc = job1['Machines'].unique()
    distinct_values_Mc=list(distinct_values_Mc)
    
    jobs = pd.DataFrame(columns=column_names)
    
    for m in range(len(distinct_values_Mc)):
        job2=job1[job1['Machines']==distinct_values_Mc[m]]
        job2 = job2.astype({'Total_Prod':'int','M/C':'int','CASTING':'int','OTHER':'int','Total_Rej':'int','Final_Prod':'int'})
        job3={'Machines':distinct_values_Mc[m], 'PRODUCT':distinct_values_Job[j], 'Total_Prod': sum(job2['Total_Prod']), 'M/C':sum(job2['M/C']), 'CASTING':sum(job2['CASTING']), 'OTHER': sum(job2['OTHER']), 'FINAL':sum(job2['Final_Prod'])}
        job3=pd.DataFrame(job3,index=[m])
        jobs=pd.concat([jobs,job3],ignore_index=True)
    job3={'Machines':'Total', 'Total_Prod':sum(jobs['Total_Prod']), 'M/C':sum(jobs['M/C']), 'CASTING':sum(jobs['CASTING']), 'OTHER':sum(jobs['OTHER']), 'FINAL':sum(jobs['FINAL'])}
    job3=pd.DataFrame(job3,index=[0])
    jobs=pd.concat([jobs,job3],ignore_index=True)
    dflist.append(jobs)
dflist
# Out:
# [    Machines PRODUCT Total_Prod M/C CASTING OTHER FINAL
#  0  M/C No. 2    test         25  10       5     3     7
#  1      Total     NaN         25  10       5     3     7,
#      Machines          PRODUCT Total_Prod M/C CASTING OTHER FINAL
#  0  M/C No. 7  ALU. BUSH ROUGH         10   1       2     3     4
#  1      Total              NaN         10   1       2     3     4,
#      Machines         PRODUCT Total_Prod M/C CASTING OTHER FINAL
#  0  M/C No. 2  S.R. Shaft THD         27   7       2     4    14
#  1  M/C No. 6  S.R. Shaft THD        109   8      10    10    81
#  2  M/C No. 4  S.R. Shaft THD        100   8       9    10    73
#  3  M/C No. 5  S.R. Shaft THD        100   8       9    10    73
#  4      Total             NaN        336  31      30    34   241]

# %%
job1=df[df['Job']==distinct_values_Job[2]]
job1=job1.loc[mask]
job1=job1.reset_index(drop=True)
job1 = job1.astype({'Total_Prod':'int','M/C':'int','CASTING':'int','OTHER':'int','Total_Rej':'int','Final_Prod':'int'})
job1
# Out:
#         Date   Machines Operator             Job  Total_Prod  M/C  CASTING  \
# 0 2023-06-02  M/C No. 2     Sukh  S.R. Shaft THD          12    1        2
# 1 2023-06-02  M/C No. 2     Sukh  S.R. Shaft THD          15    6        0
# 2 2023-07-03  M/C No. 6      som  S.R. Shaft THD           9    0        1
# 3 2023-07-05  M/C No. 4    happy  S.R. Shaft THD         100    8        9
# 4 2023-07-06  M/C No. 5    happy  S.R. Shaft THD         100    8        9
# 5 2023-07-07  M/C No. 6    happy  S.R. Shaft THD         100    8        9
#
#    OTHER  Total_Rej  Final_Prod Start_Time  End_Time time_difference1  \
# 0      3          6           6   08:00:00  12:00:00  0 days 02:30:00
# 1      1          7           8   08:30:00  13:30:00  0 days 03:30:00
# 2      0          1           8   08:10:00  21:30:00  0 days 11:50:00
# 3     10         27          73   11:00:00  21:30:00  0 days 09:00:00
# 4     10         27          73   11:50:00  22:30:00  0 days 09:10:00
# 5     10         27          73   13:00:00  23:30:00  0 days 09:00:00
#
#   time_difference
# 0        02:30:00
# 1        03:30:00
# 2        11:50:00
# 3        09:00:00
# 4        09:10:00
# 5        09:00:00

# %%
distinct_values_Mc = job1['Machines'].unique()  
distinct_values_Mc=list(distinct_values_Mc)
distinct_values_Mc
# Out:
# ['M/C No. 2', 'M/C No. 6', 'M/C No. 4', 'M/C No. 5']

# %%
machinej=[]
t_prodj=[]
mcj=[]
castj=[]
otherj=[]
final=[]
column_names = ['Machines', 'PRODUCT', 'Total_Prod','M/C','CASTING','OTHER','FINAL']

# Create an empty dataframe with the specified column names
jobs = pd.DataFrame(columns=column_names)

for m in range(len(distinct_values_Mc)):
    job2=job1[job1['Machines']==distinct_values_Mc[m]]
    job2 = job2.astype({'Total_Prod':'int','M/C':'int','CASTING':'int','OTHER':'int','Total_Rej':'int','Final_Prod':'int'})
    job3={'Machines':distinct_values_Mc[m], 'PRODUCT':distinct_values_Job[2], 'Total_Prod': sum(job2['Total_Prod']), 'M/C':sum(job2['M/C']), 'CASTING':sum(job2['CASTING']), 'OTHER': sum(job2['OTHER']), 'FINAL':sum(job2['Final_Prod'])}
    job3=pd.DataFrame(job3,index=[m])
    jobs=pd.concat([jobs,job3],ignore_index=True)
job3={'Machines':'Total', 'Total_Prod':sum(jobs['Total_Prod']), 'M/C':sum(jobs['M/C']), 'CASTING':sum(jobs['CASTING']), 'OTHER':sum(jobs['OTHER']), 'FINAL':sum(jobs['FINAL'])}
job3=pd.DataFrame(job3,index=[0])
jobs=pd.concat([jobs,job3],ignore_index=True)
jobs
# Out:
#     Machines         PRODUCT Total_Prod M/C CASTING OTHER FINAL
# 0  M/C No. 2  S.R. Shaft THD         27   7       2     4    14
# 1  M/C No. 6  S.R. Shaft THD        109   8      10    10    81
# 2  M/C No. 4  S.R. Shaft THD        100   8       9    10    73
# 3  M/C No. 5  S.R. Shaft THD        100   8       9    10    73
# 4      Total             NaN        336  31      30    34   241

# %%
job2=job1[job1['Machines']==distinct_values_Mc[1]]
job2=job2.reset_index(drop=True)
job2 = job2.astype({'Total_Prod':'int','M/C':'int','CASTING':'int','OTHER':'int','Total_Rej':'int','Final_Prod':'int'})
job2
# Out:
#         Date   Machines Operator             Job  Total_Prod  M/C  CASTING  \
# 0 2023-07-03  M/C No. 6      som  S.R. Shaft THD           9    0        1
# 1 2023-07-07  M/C No. 6    happy  S.R. Shaft THD         100    8        9
#
#    OTHER  Total_Rej  Final_Prod Start_Time  End_Time time_difference1  \
# 0      0          1           8   08:10:00  21:30:00  0 days 11:50:00
# 1     10         27          73   13:00:00  23:30:00  0 days 09:00:00
#
#   time_difference
# 0        11:50:00
# 1        09:00:00

# %%
job3={'Machines':distinct_values_Mc[1], 'PRODUCT':distinct_values_Job[2], 'Total_Prod': sum(job2['Total_Prod']),'M/C':sum(job2['M/C']), 'CASTING':sum(job2['CASTING']), 'OTHER': sum(job2['OTHER']), 'FINAL':sum(job2['Final_Prod'])}
job3=pd.DataFrame(job3,index=[0])
job3
# Out:
#     Machines         PRODUCT  Total_Prod  M/C  CASTING  OTHER  FINAL
# 0  M/C No. 6  S.R. Shaft THD         109    8       10     10     81

# %%
file_path = 'output.csv'

# Write the first dataframe to the CSV file
# dflist[0].to_csv(file_path, index=False)

# Append the remaining dataframes to the same CSV file
for i in dflist:
    i.to_csv(file_path, mode='a', header=True, index=False)

# %% [markdown]
# ## Tkinter to display dataframes

# %%
# import required modules
from tkinter import *
import pandas as pd

# Create an instance of tkinter frame
window = Tk()

# Set the size of the tkinter window
window.geometry("300x200")

# Load data from source
df = pd.read_csv("output.csv")

# Extract number of rows and columns
n_rows = df.shape[0]
n_cols = df.shape[1]

# Extracting columns from the data and
# creating text widget with some
# background color
column_names = df.columns
i=0
for j, col in enumerate(column_names):
	text = Text(window, width=16, height=1, bg = "#9BC2E6")
	text.grid(row=i,column=j)
	text.insert(INSERT, col)
	

# adding all the other rows into the grid
for i in range(n_rows):
	for j in range(n_cols):
		text = Text(window, width=16, height=1)
		text.grid(row=i+1,column=j)
		text.insert(INSERT, df.loc[i][j])

window.mainloop()
